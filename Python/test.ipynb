# %%
import numpy as np

# %%
a = [1, 2, 3, 4, 5, 6]
a1 = a[0:2]
print(a1)
# Out:
# [1, 2]

# %%
b = np.array([1, 2, 3, 4, 5, 6])
b1 = b[0:2]
print(b1)
# Out:
# [1 2]

# %%
a1[0] = 100
print("a1第一个为", a1[0])
print("a 第一个为", a[0])

print("=================")

b1[0] = 100
print("b1第一个为", b1[0])
print("b 第一个为", b[0])
# Out:
# a1第一个为 100
# a 第一个为 1
# ...
# b1第一个为 100
# b 第一个为 100

# %%
sum([[1, 2], [3]], [])
# Out:
# [1, 2, 3]

# %%
max(range(10), key=lambda x: x ** 2 - 1)
# Out:
# 9

# %%
all([1, 2, 3, 4])
# Out:
# True

# %%
bool(3)
# Out:
# True

# %%
bool()
# Out:
# False
